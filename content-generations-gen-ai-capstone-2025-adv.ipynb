# %% [markdown]
# <a href="https://www.kaggle.com/code/pranavmarwaha/content-generator-gen-ai-capstone-2025-adv?scriptVersionId=234783621" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# 🧠 Content Generator AI Assistant - Full Project¶
#
# Welcome to the Content Generator project powered by Google Gemini Pro!
#
# This notebook helps you generate engaging, AI-driven content for platforms like:
#
# 1 YouTube
#
# 2 Instagram
#
# 3 Brand Add
#
# 4 text-to-image generation Prompting
#
# 5 Blogs and Books
#
# 6 Coporate Conetent Generation
#
# 7 LinkedIn
#
#  — all from a single interface.

# %% [markdown]
# **🔍 Gen AI Capabilities Demonstrated in Content generations**
#
# In building Content generation, a next-generation AI-powered content creation assistant, we’ve successfully implemented several advanced Gen AI capabilities. These features not only enhance user experience but also ensure powerful, adaptable, and context-aware generation across use cases.
#
# Here’s a breakdown of the core Gen AI capabilities integrated into the project:
#
# ✅ 1. Structured Output / JSON Mode / Controlled Generation 📌 What It Is: This capability enables precise, predictable, and labeled content generation, allowing seamless integration with front-end apps, automation systems, and creative workflows.
#
# 🛠️ Where It’s Used: You Find all These down below
#
# YouTube Script Generator: Outputs scripts segmented by labeled timestamps (e.g., Intro, Segment 1, CTA, Outro).
#
# Brand Ad Generator: Structured outputs with clearly labeled sections like Hook, Problem, Solution, CTA.
#
# Blog & Caption Generator: Uses markdown-style breakdowns like Headings, Bullet Points, and Callouts for readability.
#
# 🎯 Why It Matters: Controlled generation ensures the output is clean, formatted, and production-ready — critical for real-world deployment in media, marketing, and publication.
#
# ✅ 2. Few-Shot Prompting 📌 What It Is: This technique involves showing the model a few examples within the prompt to guide it towards desired formats or tones — improving output quality without fine-tuning.
#
# 🛠️ Where It’s Used: everything is wriiten below in code with working functionality
#
# Instagram Reel and YouTube Captioning: Uses embedded few-shot examples to match trending formats and tones.
#
#  Brand Ad Script Generator: Demonstrates tone-matching for humorous, inspirational, or dramatic ad copy by leveraging style examples.
#
# 🎯 Why It Matters: Few-shot prompting increases versatility across different platforms (e.g., YouTube vs. Instagram) and supports brand-specific tonality — crucial for modern content strategy.
#
# ✅ 3. Function Calling 📌 What It Is: This Gen AI capability allows the model to determine when and how to call specific functions or tools during the generation process, enabling modular and dynamic content creation.
#
# 🛠️ Where It’s Used:
#
# Content Type Selector: Based on user input, the model calls the correct content generation function (e.g., YouTube Script vs. LinkedIn Post).
#
# Caption Generator for Reels: Detects whether the image is uploaded or text is input and invokes the appropriate function.
#
# 🎯 Why It Matters: Function calling transforms the assistant into an intelligent multi-tool that adapts automatically to user intent, enabling complex workflows like multimodal input parsing or format switching.
#
# ✅ 4. Long Context Window 📌 What It Is: The model can handle extensive input prompts and return detailed, coherent responses across thousands of tokens.
#
# 🛠️ Where It’s Used:
#
# Movie & Screenplay Generator: Accepts large inputs for plot summaries, character arcs, and genre, generating complete scene breakdowns and dialogue.
#
# YouTube + Blog Tools: Generate 3–5-minute scripts, long-form posts, and serialized content based on complex queries.
#
# 🎯 Why It Matters: Long-context support ensures continuity and creative depth — essential for narrative generation, storyboarding, or multi-section marketing content.
#
# ✅ 5. Grounding (Search-Augmented Prompting)  What It Is: Grounding ensures that content generated is based on real-world knowledge or up-to-date information, either via in-prompt data or external retrieval.
#
# 🛠️ Where It’s Used:
#
# Trend-Aware Ad Generator: Injects live trends (via search API or example keywords) to tailor ad suggestions to current audience interests.
#
# YouTube Video Topic Expander: Generates videos based on recent, relevant creator content or viral niches.
#
# 🎯 Why It Matters: This allows for time-sensitive, trend-driven creativity — critical for social media campaigns, SEO content, and pop culture alignment.

# %%
# !pip install -U google-generativeai==0.5.3
# Out:
# Collecting google-generativeai==0.5.3
#   Downloading google_generativeai-0.5.3-py3-none-any.whl.metadata (3.9 kB)
# Collecting google-ai-generativelanguage==0.6.3 (from google-generativeai==0.5.3)
#   Downloading google_ai_generativelanguage-0.6.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.10/dist-packages (from google-generativeai==0.5.3) (1.34.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (from google-generativeai==0.5.3) (2.155.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from google-generativeai==0.5.3) (2.27.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from google-generativeai==0.5.3) (3.20.3)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from google-generativeai==0.5.3) (2.11.0a2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from google-generativeai==0.5.3) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from google-generativeai==0.5.3) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-ai-generativelanguage==0.6.3->google-generativeai==0.5.3) (1.25.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai==0.5.3) (1.66.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai==0.5.3) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai==0.5.3) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai==0.5.3) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai==0.5.3) (4.9)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai==0.5.3) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai==0.5.3) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai==0.5.3) (4.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->google-generativeai==0.5.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.29.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->google-generativeai==0.5.3) (2.29.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.3->google-generativeai==0.5.3) (1.68.1)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.3->google-generativeai==0.5.3) (1.48.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai==0.5.3) (3.2.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai==0.5.3) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core->google-generativeai==0.5.3) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core->google-generativeai==0.5.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core->google-generativeai==0.5.3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core->google-generativeai==0.5.3) (2025.1.31)
# Downloading google_generativeai-0.5.3-py3-none-any.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.7/150.7 kB 3.1 MB/s eta 0:00:00a 0:00:01
# Downloading google_ai_generativelanguage-0.6.3-py3-none-any.whl (677 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.8/677.8 kB 16.8 MB/s eta 0:00:0000:01
# Installing collected packages: google-ai-generativelanguage, google-generativeai
#   Attempting uninstall: google-ai-generativelanguage
#     Found existing installation: google-ai-generativelanguage 0.6.10
#     Uninstalling google-ai-generativelanguage-0.6.10:
#       Successfully uninstalled google-ai-generativelanguage-0.6.10
#   Attempting uninstall: google-generativeai
#     Found existing installation: google-generativeai 0.8.3
#     Uninstalling google-generativeai-0.8.3:
#       Successfully uninstalled google-generativeai-0.8.3
# Successfully installed google-ai-generativelanguage-0.6.3 google-generativeai-0.5.3

# %%
import google.generativeai as genai
from kaggle_secrets import UserSecretsClient

# %%
GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
genai.configure(api_key=GOOGLE_API_KEY)
model = genai.GenerativeModel(model_name="models/gemini-1.5-pro-latest")

# %% [markdown]
# * 🎬 1. YouTube Content Generation¶
# Features:
#
# * 🎬 Title (1 catchy headline)
# * 📄 Description (150-200 words + hashtags)
# * Intro: A hook with a welcome message (~30 seconds)
# * Main Content: Break the rest of the time into 3–5 logical segments with timestamps and titles (e.g., 0:30–2:00: "Segment Name").
# * Outro: Wrap-up and call to action (~30 seconds)

# %%
# Generate Youtube Conetent
def generate_youtube_script(topic, duration_minutes):
    total_seconds = duration_minutes * 60
    prompt = f"""
You are a YouTube content generation assistant.

Generate a full video content package for the topic: "{topic}"
The total duration should be approx {duration_minutes} minutes ({total_seconds} seconds).

Provide the following:

1. 🎬 Title (1 catchy headline)
2. 📄 Description (150-200 words + hashtags)
3. 📝 Video Script with time-based segments:
   - Intro: A hook with a welcome message (~30 seconds)
   - Main Content: Break the rest of the time into 3–5 logical segments with timestamps and titles (e.g., 0:30–2:00: "Segment Name").
   - Outro: Wrap-up and call to action (~30 seconds)

Make it engaging, slightly enthusiastic, informative, and beginner-friendly. Output in clearly labeled sections.
"""
    response = model.generate_content(prompt)
    return response.text

# %%
topic = "China Dark Factory Era"
duration = 3  # minutes

output = generate_youtube_script(topic, duration)
print(output)
# Out:
# 🎬 **Title:**  Lights Out Manufacturing: Inside China's Dark Factories
#
# 📄 **Description:**
# Are you ready to step into the future of manufacturing? China's "dark factories" are revolutionizing how things are made, operating almost entirely without human intervention.  Imagine factories humming with robotic arms and automated systems, working 24/7 with the lights off!  This video explores the rise of these highly automated facilities, the technologies driving them, and their potential impact on global manufacturing. We'll delve into the benefits, like increased efficiency and lower costs, but also discuss the potential downsides, such as job displacement and ethical concerns.  Join us as we explore this fascinating and rapidly evolving landscape. Are dark factories the future of production or a glimpse into a dystopian reality? Let us know your thoughts in the comments!
#
# #DarkFactories #Automation #ChinaManufacturing #Industry40 #Robotics #FutureofWork #AI #ArtificialIntelligence #ManufacturingTechnology #Tech #Innovation #ChineseEconomy #GlobalEconomy #SupplyChain #Manufacturing
#
#
# 📝 **Video Script:**
#
# **(0:00-0:30) Intro: Welcome to the Dark Side of Manufacturing**
#
# [Upbeat music intro with visuals of futuristic factory renderings and robotic arms]
#
# Hey everyone, and welcome back to the channel! Today, we're diving into a topic that's straight out of a sci-fi movie: China's Dark Factories. Now, before you imagine some shady underground operation, let me clarify. "Dark" refers to the fact that these factories can operate with the lights off because they're almost entirely automated! Pretty cool, huh?  Let's explore what this means for the future of manufacturing.
#
# **(0:30-1:00) Segment 1:  Rise of the Machines: What are Dark Factories?**
#
# [Visuals: footage of automated assembly lines, robots welding and packing]
#
# Essentially, dark factories are highly automated manufacturing facilities that require minimal human intervention. Think robots performing complex tasks, automated guided vehicles transporting materials, and sophisticated software systems controlling the entire operation.  This allows production to continue around the clock, boosting efficiency and significantly reducing labor costs.  China's leading the charge in this area, driven by rising labor costs and advancements in technology.
#
# **(1:00-1:30) Segment 2: The Tech Powering the Darkness: AI & Robotics**
#
# [Visuals: close-ups of robotic components, AI interfaces, data visualizations]
#
# The heart of these dark factories lies in the powerful combination of artificial intelligence and robotics. AI algorithms optimize production processes, predict maintenance needs, and even adapt to changing market demands in real-time.  Advanced robotics carry out intricate assembly, quality control, and even packaging – tasks that previously required human dexterity and decision-making.
#
# **(1:30-2:00) Segment 3:  The Bright and Dark Sides:  Pros & Cons**
#
# [Visuals: infographics comparing traditional vs. automated manufacturing; footage of workers being retrained]
#
# While the potential benefits of dark factories are huge – increased productivity, lower costs, and faster production cycles – there are also significant challenges.  Job displacement is a major concern, with many fearing widespread unemployment as automation takes over.  There are also ethical considerations regarding the role of humans in an increasingly automated world and the potential for increased economic inequality.
#
# **(2:00-2:30) Segment 4: The Future is Automated:  Global Impact**
#
# [Visuals: world map highlighting manufacturing hubs, futuristic cityscapes]
#
# China's dark factories are not just a local phenomenon; they represent a significant shift in the global manufacturing landscape. This trend towards automation is likely to spread to other countries, forcing industries worldwide to adapt.  What does this mean for the future of work and the global economy? That's a question we need to address now.
#
#
# **(2:30-3:00) Outro: Lights Out, Discussion On!**
#
# [Upbeat music outro with end screen graphics and social media links]
#
# So, what do you think about the rise of dark factories? Is it a positive step forward or a cause for concern? Let us know your thoughts in the comments below! Be sure to like and subscribe for more fascinating insights into the world of technology and innovation. Thanks for watching, and we'll see you in the next video!

# %% [markdown]
# 📸 2. Instagram Content (Post + Reels)¶ Features:
#
# * Hook
# * 3-5 short scenes or segments
# * On-screen text suggestions
# * Audio or music style
# * Hashtags

# %%
def generate_instagram_caption(image_description):
    prompt = f"""
Generate a mood-based Instagram caption for an image that is: {image_description}
Return only the caption.
"""
    return model.generate_content(prompt).text

def generate_instagram_reel_script(topic):
    prompt = f"""
Generate a creative Instagram Reels script for the topic: {topic}.
Include
- Hook
- 3-5 short scenes or segments
- On-screen text suggestions
- Audio or music style
- Hashtags
"""
    return model.generate_content(prompt).text

# %%
print(generate_instagram_reel_script("Evening of Bengluru"))
# Out:
# ## Instagram Reels Script: Evening of Bengaluru
#
# **Hook:** Time-lapse of the sun setting over the Bengaluru skyline, transitioning into a vibrant night scene.
#
# **On-screen text:**  "Bengaluru After Dark ✨"
#
# **Audio/Music Style:** Upbeat, trendy instrumental music with a touch of Indian influence.  Think Ritviz or Nucleya.
#
# **Scene 1:**
#
# * **Visual:**  Street food vendor preparing Masala Dosa. Close-up shots of the sizzling dosa, the chutney, and the sambar.
# * **On-screen text:** "Street Food Dreams"
# * **Sound:** Sizzling sounds, vendor's chatter (optional, with subtitles).
#
# **Scene 2:**
#
# * **Visual:** Fast-paced montage of people commuting home on bikes, autos, and buses.  Intersperse with shots of vibrant neon signs and streetlights illuminating the city.
# * **On-screen text:** "City That Never Sleeps"
# * **Sound:** Traffic sounds mixed with the background music.
#
# **Scene 3:**
#
# * **Visual:**  People chilling at a rooftop bar/restaurant, enjoying drinks and conversations. Show the city lights twinkling in the background.
# * **On-screen text:** "Rooftop Vibes"
# * **Sound:**  Chatter, clinking glasses, music from the bar.
#
#
# **Scene 4:**
#
# * **Visual:**  Street musician performing near a park, surrounded by a small crowd.
# * **On-screen text:**  "Hidden Gems"
# * **Sound:**  The musician's performance.
#
#
# **Scene 5 (Optional):**
#
# * **Visual:** Time-lapse of traffic flowing through a busy intersection, creating light trails.
# * **On-screen text:** "The Pulse of the City"
# * **Sound:** Background music intensifies.
#
#
# **Ending:** Final shot of the Bengaluru skyline at night, with the moon shining brightly.
#
# **On-screen text:** "Namma Bengaluru ❤️"
#
# **Hashtags:** #Bengaluru #Bangalore #NammaBengaluru #BengaluruNightlife #India #IncredibleIndia #StreetFood #CityLife #Travel #Explore #Night #Vibes #Rooftop #Music #Culture #Karnataka #Travelgram #Reels #InstagramReels #ExploreBengaluru #EveningVibes #CityLights
#
# **Additional Tips:**
#
# * Keep the reel short and snappy (under 30 seconds).
# * Use smooth transitions between scenes.
# * Incorporate trending filters or effects if appropriate.
# * Encourage engagement by asking a question in the caption (e.g., "What's your favourite thing about Bengaluru evenings?").
# * Tag relevant accounts (e.g., local businesses, tourism boards).
#
#
# This script provides a framework. Feel free to adapt and personalize it based on your own experiences and creativity. Good luck!

# %% [markdown]
# 🧠 3. Brand Ad Script Generation¶ Features:
#
# * 🎯 Title: Catchy campaign or ad headline
# * ✨ Hook: Attention-grabbing first line or scene (0:00 timestamp)
# * 🎬 Ad Script (with timestamps and segments), broken down as:
# * Hook/Scene Opener (0:00–X)
# * Product Highlight / Value Prop
# * Emotional or Relatable Use Case
# * Call to Action
# * Outro/Tagline/Closing Note

# %%
def generate_brand_ad_script(brand, product_description, duration_seconds, audience=None):
    minutes = duration_seconds // 60
    seconds = duration_seconds % 60
    formatted_duration = f"{minutes}m {seconds}s" if minutes else f"{seconds}s"

    prompt = f"""
You are an expert ad copywriter.

Create a full video ad script for a brand/product with the following details:

Brand/Product Name: "{brand}"
Product Description: "{product_description}"
{"Target Audience: " + audience if audience else ""}
Desired Ad Length: {formatted_duration}

Output the following:
1. Title: Catchy campaign or ad headline
2. ✨ Hook: Attention-grabbing first line or scene (0:00 timestamp)
3. 🎬 Ad Script (with timestamps and segments), broken down as:
    - Hook/Scene Opener (0:00–X)
    - Product Highlight / Value Prop
    - Emotional or Relatable Use Case
    - Call to Action
    - Outro/Tagline/Closing Note

Keep it high-conversion, clear, concise, and emotionally appealing. Label sections clearly. Use timestamps based on total duration: {duration_seconds} seconds.
"""

    response = model.generate_content(prompt)
    return response.text

# %%
brand = "Wanderlust Explorers,"
product_description = "Wanderlust Explorers is a travel company that specializes in creating unforgettable journeys for those with a thirst for adventure and a desire to connect with the world's diverse cultures."
audience = "Men and Women aged 25–75 who wants to enjoy their life and explore the world"
duration = 60
print(generate_brand_ad_script(brand, product_description, duration, audience))
# Out:
# 1. **Title:**  Unleash Your Inner Explorer
#
# 2. **✨ Hook:** (Scene: Stunning montage of diverse landscapes flashing by – mountains, jungles, bustling markets, serene beaches)  **(0:00)**  *Whispering voiceover:*  "Remember that feeling? The thrill of the unknown..."
#
# 3. **🎬 Ad Script:**
#
#     **(Hook/Scene Opener - 0:00-0:05)**
#
#     *(Visuals: Fast-paced montage continues, showcasing diverse activities like hiking, kayaking, interacting with locals, exploring ancient ruins)*
#
#     *Whispering voiceover:* "...The joy of discovering something new.  The magic of connecting with a world beyond your everyday."
#
#
#     **(Product Highlight / Value Prop - 0:05-0:20)**
#
#     *(Visuals: Transition to slightly slower, more focused shots of small groups enjoying Wanderlust Explorers experiences.  Emphasis on authentic cultural immersion, comfortable yet adventurous accommodations, and expert local guides.)*
#
#     *Warm, inviting voiceover:* "At Wanderlust Explorers, we craft unforgettable journeys for those who crave more than just a vacation. We believe travel is about transformation. It's about immersing yourself in vibrant cultures, forging genuine connections, and discovering the hidden wonders of our planet."
#
#     **(Emotional or Relatable Use Case - 0:20-0:40)**
#
#     *(Visuals: Show a mix of solo travelers, couples, and friends enjoying different aspects of a Wanderlust Explorers trip.  Focus on genuine moments of laughter, connection, and awe. One scene could show someone learning a local craft, another sharing a meal with a local family.)*
#
#     *Inspirational voiceover:* "Imagine waking up to the sounds of a bustling Moroccan souk, learning to cook traditional Thai cuisine from a local chef, or trekking through the breathtaking Himalayas with newfound friends.  These are the experiences that shape us, that stay with us long after we've returned home.  These are the stories you'll share for a lifetime."
#
#     **(Call to Action - 0:40-0:55)**
#
#     *(Visuals: Show website address and social media handles.  Showcase a limited-time offer, e.g., "Book your dream adventure today and receive 10% off your first trip.")*
#
#     *Upbeat, encouraging voiceover:* "Ready to unleash your inner explorer? Visit WanderlustExplorers.com or follow us on social media to discover our curated collection of small-group adventures. Don't just travel, *experience.*"
#
#     **(Outro/Tagline/Closing Note - 0:55-1:00)**
#
#     *(Visuals: Final stunning shot of a breathtaking vista, overlaid with the Wanderlust Explorers logo.)*
#
#     *Whispering voiceover:* "Wanderlust Explorers.  Live the journey."

# %% [markdown]
# 📝 4. Blog Generation¶
#
# Features:
#
# 🖊️ Title
#
# 🧾 Subheadings with explanations
#
# 🔍 SEO keywords

# %%
def generate_blog_or_book(topic, type="blog", genre="non-fiction"):
    prompt = f""" You are expert in creatig blog and books
Create a {type} on the topic: "{topic}".
If type is book, provide:
- 📖 Title
- 📑 Chapter breakdown (5–8)
- 📘 Summary for each chapter
- 🧵 Narrative tone

If type is blog, include:
- 🖊️ Title
- 🧾 Subheadings with explanations
- 🔍 SEO keywords
"""
    return model.generate_content(prompt).text

# %%
print(generate_blog_or_book("I have participated in Microsoft Gen AI fest and learn Create agentic AIsolutions with Azure AI Foundry", "blog"))
# Out:
# ## Blog Post: Unleashing Agentic AI: My Journey at the Microsoft Gen AI Fest and Azure AI Foundry
#
# **🖊️ Title:** Unleashing Agentic AI: My Journey at the Microsoft Gen AI Fest and Azure AI Foundry
#
# **🧾 Subheadings with explanations:**
#
# * **Introduction: A Glimpse into the Future of AI** -  Brief overview of the Gen AI Fest and its focus on agentic AI. Briefly explain what agentic AI is (AI that can act autonomously and achieve goals). Excitement about attending the fest and the Azure AI Foundry workshop.
# * **Diving Deep with Azure AI Foundry:** -  Explanation of the Azure AI Foundry and its capabilities. Discuss the tools and resources provided to develop and deploy agentic AI solutions. Mention any specific features or services that stood out.
# * **Building Agentic AI: From Concept to Creation** -  Focus on the practical aspects of building agentic AI solutions.  Share a brief example of a project worked on or a concept explored during the fest.  Describe the development process and challenges encountered.
# * **Key Learnings and Takeaways:** -  Summarize the most important insights gained from the fest and the Azure AI Foundry.  Discuss specific technologies or approaches that were particularly impactful. Mention networking opportunities and interactions with experts.
# * **The Future of Agentic AI and Its Impact** -  Explore the potential impact of agentic AI across various industries. Share thoughts on the future of this technology and its ethical implications.  Express personal enthusiasm for continuing exploration in this field.
# * **Get Started with Agentic AI and Azure AI Foundry:** -  Provide resources and links for readers who want to learn more or get started with agentic AI and Azure AI Foundry. Encourage community engagement and further exploration.
#
# **🔍 SEO Keywords:**
#
# Microsoft Gen AI Fest, Azure AI Foundry, Agentic AI, Artificial Intelligence, AI Development, AI Solutions, Microsoft AI, AI Tools, Autonomous Agents, AI Future, Machine Learning, Deep Learning, AI Workshop, AI Conference, Cloud Computing, AI Ethics,  Cognitive Services.
#
#
#
# ---
#
# **(If this were a book instead of a blog post):**
#
#
# **📖 Title:**  Building Agentic AI: A Practical Guide with Azure AI Foundry
#
#
# **📑 Chapter Breakdown:**
#
# 1. Introduction to Agentic AI
# 2. The Power of Azure AI Foundry
# 3. Designing and Building Agentic AI Agents
# 4. Working with Data and Models in Azure AI Foundry
# 5. Deploying and Managing Agentic AI Solutions
# 6. Ethical Considerations for Agentic AI
# 7. Real-World Applications of Agentic AI
# 8. The Future of Agentic AI
#
#
# **📘 Summary for each chapter:**
#
# 1. **Introduction to Agentic AI:** Defines agentic AI, its key characteristics, and its potential impact across various domains.  Explores the evolution of AI leading to the emergence of agentic systems.
#
# 2. **The Power of Azure AI Foundry:**  Deep dive into Azure AI Foundry as a platform for developing and deploying agentic AI. Covers its key features, tools, and resources.
#
# 3. **Designing and Building Agentic AI Agents:**  Focuses on the practical steps involved in designing and building agentic AI agents, including architecture, goal setting, decision-making processes, and interaction design.
#
# 4. **Working with Data and Models in Azure AI Foundry:** Explains how to leverage data and models within the Azure AI Foundry ecosystem for training and refining agentic AI agents. Covers data preparation, model selection, and training techniques.
#
# 5. **Deploying and Managing Agentic AI Solutions:**  Details the process of deploying agentic AI solutions into real-world environments and managing their lifecycle. Discusses monitoring, scaling, and maintenance strategies.
#
# 6. **Ethical Considerations for Agentic AI:** Explores the ethical implications of deploying agentic AI, including bias, transparency, accountability, and safety.  Discusses best practices for responsible AI development.
#
# 7. **Real-World Applications of Agentic AI:** Showcases real-world examples of agentic AI in action across different industries, such as healthcare, finance, and manufacturing.
#
# 8. **The Future of Agentic AI:**  Speculates on the future trajectory of agentic AI, its potential advancements, and its long-term societal impact.
#
#
# **🧵 Narrative Tone:**  Practical, informative, and engaging. The book will adopt a hands-on approach, guiding readers through the process of building agentic AI solutions using Azure AI Foundry.  It will also address the ethical considerations and societal implications of this powerful technology.

# %% [markdown]
# 5. Text to image prompt Generation

# %%
def generate_text_to_image_prompt(scene_description, style="realistic"):
    prompt = f"""
Convert this scene into a text-to-image prompt for an AI art generator.

Scene: {scene_description}
Preferred Style: {style}

Format:
- 🎨 Prompt for text-to-image generation (detailed, descriptive, with artistic flair)
"""
    return model.generate_content(prompt).text

# %%
print(generate_text_to_image_prompt("A rich guy city in night driving luxary car", "anime"))
# Out:
# - 🎨 Prompt for text-to-image generation:
#
# A sleek, futuristic luxury car, bathed in the vibrant neon glow of a rich anime cityscape at night.  The car, maybe a long, low-slung sports car or a high-tech limousine with glowing accents, is cruising down a rain-slicked street reflecting the city lights.  Inside, a silhouette of a wealthy-looking anime character, sharp jawline and styled hair, is visible through the tinted windows.  Towering skyscrapers pierce the night sky, adorned with holographic advertisements and intricate architectural details. Flying cars weave between the buildings, leaving trails of light.  The overall atmosphere is one of opulence, technology, and speed. Anime style, vibrant colors, cinematic lighting, high detail, 8k, trending on artstation.  Think cyberpunk meets high-fashion.  Emphasis on reflections, dynamic pose of the car, and the feeling of fast movement.  Include subtle details like light trails, rain droplets on the car's surface, and the glow of the car's interior.

# %% [markdown]
# * ** Now get the generated prompt and use it in any text to image generation to get better results.**

# %% [markdown]
# 💡Here is a sample output generated using ChatGPT using the prompt we generated.

# %% [markdown]
# ![ChatGPT Image Apr 19, 2025, 10_50_00 AM.jpg](attachment:467c9130-6fc0-41d0-9d46-ab9bc160435a.jpg)

# %% [markdown]
# 💼 6. Coperate content Generation Features:
#
# * 🗣️ Opening Greeting
# * 💬 Main Announcement or Message
# * ✅ Action Points or Takeaways
# * 📢 Closing Note or Motivation

# %%
def generate_internal_corp_script(purpose, company_name, tone="professional"):
    prompt = f"""
You're the communications head for {company_name}.

Generate a script/message for internal use.

Purpose: {purpose}
Tone: {tone}

Include:
1. 🗣️ Opening Greeting
2. 💬 Main Announcement or Message
3. ✅ Action Points or Takeaways
4. 📢 Closing Note or Motivation

Make it clear, respectful, and aligned with corporate tone.
"""
    return model.generate_content(prompt).text

# %%
print(generate_internal_corp_script("Announce that we are going to start an import and export bussiness", "SwiftCargo"))
# Out:
# Subject: SwiftCargo Expands into Import & Export Business!
#
# 🗣️ **Opening Greeting:**
#
# Hello SwiftCargo Team,
#
# I'm thrilled to share some exciting news that marks a significant milestone in SwiftCargo's growth.
#
#
# 💬 **Main Announcement or Message:**
#
# As many of you know, SwiftCargo has been diligently exploring strategic opportunities to expand our service offerings and reach new markets. Today, I'm pleased to announce that we are officially launching our import and export business! This strategic move will allow us to diversify our portfolio, tap into new revenue streams, and solidify our position as a leading logistics provider.
#
# This expansion opens up a world of possibilities for SwiftCargo, allowing us to connect businesses with global markets and facilitate seamless international trade.  We'll be leveraging our existing infrastructure and expertise in logistics and transportation to provide efficient and reliable import and export solutions to our clients.
#
#
# ✅ **Action Points or Takeaways:**
#
# * **Training:** Over the coming weeks, dedicated training sessions will be provided to equip everyone with the necessary knowledge and skills related to import/export procedures, documentation, and regulatory compliance.  More details on these training sessions, including schedules and registration, will be shared shortly.
# * **Communication:**  Stay tuned for further updates and communications regarding specific roles, responsibilities, and departmental impacts.  Regular updates will be disseminated through email, company intranet, and team meetings.
# * **Questions:** If you have any immediate questions, please direct them to [Designated Point of Contact – Name/Department/Email Address].
#
#
# 📢 **Closing Note or Motivation:**
#
# This expansion represents a tremendous opportunity for SwiftCargo and for each of you.  Your dedication, expertise, and collaborative spirit will be essential as we embark on this exciting new chapter.  Let’s work together to make this venture a resounding success!
#
#
# Sincerely,
#
# [Your Name]
#
# Head of Communications, SwiftCargo

# %% [markdown]
# 📥 7. Linkedin post Generation
#
# * Features:
#
# * 🔥 Hook (1–2 lines to grab attention)
#
# * 🧠 Insight / Experience Share (3–5 short paras)
#
# * 🚀 Takeaway or Motivation
#
# * 🙌 CTA (comment/like/share)

# %%
def generate_linkedin_content(topic, purpose="inspiration", tone="authentic"):
    prompt = f"""
You're a thought leader and storyteller on LinkedIn.

Write a post on: "{topic}"
Purpose: {purpose}
Tone: {tone}

Structure:
1. 🔥 Hook (1–2 lines to grab attention)
2. 🧠 Insight / Experience Share (3–5 short paras)
3. 🚀 Takeaway or Motivation
4. 🙌 CTA (comment/like/share)

Be real, insightful, and use a human voice.
"""
    return model.generate_content(prompt).text

# %%
# ✅ Example
print(generate_linkedin_content("I started learing DeeP learing", purpose="reflection", tone="happy"))
# Out:
# 🔥 The neural networks have officially ensnared me!  I've finally taken the plunge and started learning deep learning, and let me tell you, it's like stepping into a whole new universe.
#
# 🧠 I've always been fascinated by AI, but honestly, the math and the complexity felt a bit intimidating.  For a while, I contented myself with reading articles and watching explainer videos, feeling a mix of awe and mild terror.  Then, last week, something clicked. I stumbled across a fantastic online course, and suddenly the fear morphed into excitement.  It’s early days, but building my first (very basic) neural network felt incredibly empowering.
#
# It’s funny how different the learning experience is from other fields I’ve explored. It's less like stacking bricks and more like nurturing a garden. You plant the seeds (your code), water them with data, and then watch (sometimes with bated breath!) to see how they grow. There are definitely moments of frustration, like when your model stubbornly refuses to learn, but the breakthroughs, however small, are pure gold.
#
# What I'm realizing is that deep learning isn't just about algorithms and code; it's about a whole new way of thinking.  It's about understanding how machines can learn, how they can perceive the world, and ultimately, how they can help us solve complex problems.
#
# 🚀 This journey is just beginning, but I'm already hooked. The potential of deep learning feels vast and transformative, and I'm eager to explore its depths.  If you're on the fence about diving into this world, I urge you to take the leap. It's challenging, yes, but incredibly rewarding.
#
# 🙌 What about you? Have you dipped your toes into the deep learning waters?  Share your experiences and any resources you've found helpful in the comments below! Let's learn together!  #deeplearning #AI #machinelearning #neuralnetworks #learning #career #technology
